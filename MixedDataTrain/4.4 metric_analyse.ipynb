# %% [markdown]
# # Metric Analysis

# %%
import os
import pandas as pd
current_path = os.getcwd()
current_path
# Out:
# 'c:\\Users\\Fortyfour\\Desktop\\graduation_design\\Scripts_git\\MixedDataTrain'

# %%
direct_mix_metrics = pd.read_csv(os.path.join(current_path, 'DirectMix', 'model_metrics.csv'))
self_learning_metrics = pd.read_csv(os.path.join(current_path, 'SelfLearning', 'model_metrics.csv'))
stacking_metrics = pd.read_csv(os.path.join(current_path, 'Stacking', 'model_metrics.csv'))

# %%
mix_metrics = pd.concat([direct_mix_metrics, self_learning_metrics, stacking_metrics], axis=0, ignore_index=True)

# %%
mix_metrics = mix_metrics.replace({'Train_set': {'meta': 'mix'}})
mix_metrics
# Out:
#                     Model Error_Type Train_set Test_set        R²      RMSE  \
# 0      Direct Mix XGBoost      Train       mix      mix  0.915122  0.416122
# 1      Direct Mix XGBoost       Test       mix      dft  0.820017  0.619787
# 2      Direct Mix XGBoost       Test       mix      exp  0.406535  0.933236
# 3      Direct Mix XGBoost       Test       mix      mix  0.716388  0.736325
# 4   Self Learning XGBoost      Train       mix      mix  0.971521  0.228275
# 5   Self Learning XGBoost       Test       mix      dft  0.685462  0.819339
# 6   Self Learning XGBoost       Test       mix      exp  0.816929  0.518326
# 7   Self Learning XGBoost       Test       mix      mix  0.726553  0.723009
# 8        Stacking XGBoost      Train       mix     meta  0.994471  0.087510
# 9        Stacking XGBoost       Test       mix      dft  0.537206  0.993850
# 10       Stacking XGBoost       Test       mix      exp  0.870737  0.435543
# 11       Stacking XGBoost       Test       mix      mix  0.639421  0.830247
#
#          MAE
# 0   0.246549
# 1   0.400467
# 2   0.730649
# 3   0.513856
# 4   0.170405
# 5   0.538090
# 6   0.346339
# 7   0.470995
# 8   0.050733
# 9   0.794383
# 10  0.272570
# 11  0.613598

# %%
mix_metrics = mix_metrics[mix_metrics['Error_Type'] != 'Train']
mix_metrics
# Out:
#                     Model Error_Type Train_set Test_set        R²      RMSE  \
# 1      Direct Mix XGBoost       Test       mix      dft  0.820017  0.619787
# 2      Direct Mix XGBoost       Test       mix      exp  0.406535  0.933236
# 3      Direct Mix XGBoost       Test       mix      mix  0.716388  0.736325
# 5   Self Learning XGBoost       Test       mix      dft  0.685462  0.819339
# 6   Self Learning XGBoost       Test       mix      exp  0.816929  0.518326
# 7   Self Learning XGBoost       Test       mix      mix  0.726553  0.723009
# 9        Stacking XGBoost       Test       mix      dft  0.537206  0.993850
# 10       Stacking XGBoost       Test       mix      exp  0.870737  0.435543
# 11       Stacking XGBoost       Test       mix      mix  0.639421  0.830247
#
#          MAE
# 1   0.400467
# 2   0.730649
# 3   0.513856
# 5   0.538090
# 6   0.346339
# 7   0.470995
# 9   0.794383
# 10  0.272570
# 11  0.613598

# %%
mix_metrics.drop(columns=['Error_Type'], inplace=True)
# Out:
# C:\Users\Fortyfour\AppData\Local\Temp\ipykernel_3672\1156461529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mix_metrics.drop(columns=['Error_Type'], inplace=True)

# %%
mix_metrics
# Out:
#                     Model Train_set Test_set        R²      RMSE       MAE
# 1      Direct Mix XGBoost       mix      dft  0.820017  0.619787  0.400467
# 2      Direct Mix XGBoost       mix      exp  0.406535  0.933236  0.730649
# 3      Direct Mix XGBoost       mix      mix  0.716388  0.736325  0.513856
# 5   Self Learning XGBoost       mix      dft  0.685462  0.819339  0.538090
# 6   Self Learning XGBoost       mix      exp  0.816929  0.518326  0.346339
# 7   Self Learning XGBoost       mix      mix  0.726553  0.723009  0.470995
# 9        Stacking XGBoost       mix      dft  0.537206  0.993850  0.794383
# 10       Stacking XGBoost       mix      exp  0.870737  0.435543  0.272570
# 11       Stacking XGBoost       mix      mix  0.639421  0.830247  0.613598

# %%
exp_dft_metrics = pd.read_csv(os.path.join(current_path, '../SingleModels', 'model_metrics.csv'))
exp_dft_metrics = exp_dft_metrics[exp_dft_metrics['Model'] == 'XGBoost']

# %%
exp_dft_metrics.drop(columns=['MAPE'], inplace=True)
exp_dft_metrics.reset_index(drop=True, inplace=True)
exp_dft_metrics
# Out:
#      Model Train_set Test_set        R²      RMSE       MAE
# 0  XGBoost       dft      dft  0.819994  0.619826  0.401085
# 1  XGBoost       dft      exp  0.377254  0.934225  0.739763
# 2  XGBoost       dft      mix  0.719518  0.732250  0.509808
# 3  XGBoost       exp      exp  0.891362  0.399287  0.246365
# 4  XGBoost       exp      dft  0.285749  1.234674  0.952408
# 5  XGBoost       exp      mix  0.450443  1.024975  0.712478

# %%
exp_dft_metrics.loc[:3, 'Model'] = 'DFT XGBoost'
exp_dft_metrics.loc[3:, 'Model'] = 'EXP XGBoost'
exp_dft_metrics
# Out:
#          Model Train_set Test_set        R²      RMSE       MAE
# 0  DFT XGBoost       dft      dft  0.819994  0.619826  0.401085
# 1  DFT XGBoost       dft      exp  0.377254  0.934225  0.739763
# 2  DFT XGBoost       dft      mix  0.719518  0.732250  0.509808
# 3  EXP XGBoost       exp      exp  0.891362  0.399287  0.246365
# 4  EXP XGBoost       exp      dft  0.285749  1.234674  0.952408
# 5  EXP XGBoost       exp      mix  0.450443  1.024975  0.712478

# %%
metrics = pd.concat([exp_dft_metrics, mix_metrics], axis=0, ignore_index=True)
metrics
# Out:
#                     Model Train_set Test_set        R²      RMSE       MAE
# 0             DFT XGBoost       dft      dft  0.819994  0.619826  0.401085
# 1             DFT XGBoost       dft      exp  0.377254  0.934225  0.739763
# 2             DFT XGBoost       dft      mix  0.719518  0.732250  0.509808
# 3             EXP XGBoost       exp      exp  0.891362  0.399287  0.246365
# 4             EXP XGBoost       exp      dft  0.285749  1.234674  0.952408
# 5             EXP XGBoost       exp      mix  0.450443  1.024975  0.712478
# 6      Direct Mix XGBoost       mix      dft  0.820017  0.619787  0.400467
# 7      Direct Mix XGBoost       mix      exp  0.406535  0.933236  0.730649
# 8      Direct Mix XGBoost       mix      mix  0.716388  0.736325  0.513856
# 9   Self Learning XGBoost       mix      dft  0.685462  0.819339  0.538090
# 10  Self Learning XGBoost       mix      exp  0.816929  0.518326  0.346339
# 11  Self Learning XGBoost       mix      mix  0.726553  0.723009  0.470995
# 12       Stacking XGBoost       mix      dft  0.537206  0.993850  0.794383
# 13       Stacking XGBoost       mix      exp  0.870737  0.435543  0.272570
# 14       Stacking XGBoost       mix      mix  0.639421  0.830247  0.613598

# %%
# calulate the mean of the metrics
metrics.groupby('Model')['RMSE'].mean()
# Out:
# Model
# DFT XGBoost              0.762100
# Direct Mix XGBoost       0.763116
# EXP XGBoost              0.886312
# Self Learning XGBoost    0.686891
# Stacking XGBoost         0.753213
# Name: RMSE, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. draw the rmse comparison figure

# set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(14, 8), dpi=300)

# get unique models
models = metrics['Model'].unique()
test_sets = metrics['Test_set'].unique()

# prepare data for plotting
plot_data = []
for model in models:
    model_metrics = metrics[metrics['Model'] == model]
    for _, row in model_metrics.iterrows():
        plot_data.append({
            'Model': row['Model'],
            'Train_set': row['Train_set'],
            'Test_set': row['Test_set'],
            'RMSE': row['RMSE']
        })

plot_df = pd.DataFrame(plot_data)


# create bar plot
ax = sns.barplot(
    x='Model', 
    y='RMSE', 
    hue='Test_set',
    data=plot_df,
    palette='Set2',
    alpha=0.7
)

# add data labels
# add data labels
for p in ax.patches:
    if p.get_height() > 0.01:
        ax.annotate(f'{p.get_height():.3f}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='bottom', fontsize=10)

# add legend
handles, labels = ax.get_legend_handles_labels()
test_set_legend = plt.legend(handles, labels, title='Test Set', loc='upper left')
ax.add_artist(test_set_legend)

# 
plt.xlabel('Model', fontsize=14, weight='bold')
plt.ylabel('RMSE(eV)', fontsize=14, weight='bold')
plt.title('RMSE of Different Models on Various Test Sets', fontsize=16, weight='bold')

plt.tight_layout()

# save the figure
plt.savefig(os.path.join(current_path, 'rmse_comparison_of_mix_model.png'), dpi=300, bbox_inches='tight')
plt.show()
